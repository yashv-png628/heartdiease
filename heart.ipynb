# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
heart1_dataset=pd.read_csv("heart1.csv")

# %%
heart1_dataset
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
heart1_dataset.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
heart1_dataset.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
heart1_dataset.shape
# Out:
# (1025, 14)

# %%
heart1_dataset.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
heart1_dataset.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
heart1_dataset.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
print(heart1_dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB
# None

# %%
plt.figure(figsize=(14,15))
sns.heatmap(heart1_dataset.corr(),annot=True,cmap='terrain')

# %%
sns.pairplot(data=heart1_dataset)

# %%
heart1_dataset.plot(kind='box',subplots=True,layout=(5,3),figsize=(12,12))
plt.show()

# %%
sns.catplot(data=heart1_dataset,x='sex',y='age',hue='target',palette='husl')

# %%
sns.barplot(data=heart1_dataset,x='sex',y='chol',hue='target',palette='spring')

# %%
heart1_dataset['sex'].value_counts()
# Out:
# 1    713
# 0    312
# Name: sex, dtype: int64

# %%
heart1_dataset['target'].value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
heart1_dataset['thal'].value_counts()
# Out:
# 2    544
# 3    410
# 1     64
# 0      7
# Name: thal, dtype: int64

# %%
sns.countplot(x='sex',data=heart1_dataset,palette='husl',hue='target')

# %%
sns.countplot(x='target',palette='BuGn',data=heart1_dataset)

# %%
sns.countplot(x='ca',hue='target',data=heart1_dataset)

# %%
heart1_dataset['ca'].value_counts()
# Out:
# 0    578
# 1    226
# 2    134
# 3     69
# 4     18
# Name: ca, dtype: int64

# %%
sns.countplot(x='thal',data=heart1_dataset,hue='target',palette='BuPu')

# %%
sns.countplot(x='thal',hue='sex',data=heart1_dataset,palette='terrain')

# %%
heart1_dataset['cp'].value_counts()
# Out:
# 0    497
# 2    284
# 1    167
# 3     77
# Name: cp, dtype: int64

# %%
sns.countplot(x='cp',hue='target',data=heart1_dataset,palette='rocket')

# %%
sns.countplot(x='cp',hue='sex',data=heart1_dataset,palette='BrBG')

# %%
sns.boxplot(x='sex',y='chol',hue='target',palette='seismic',data=heart1_dataset)

# %%
sns.barplot(x='sex',y='cp',hue='target',data=heart1_dataset,palette='cividis')

# %%
sns.barplot(x='sex',y='thal',data=heart1_dataset,hue='target',palette='nipy_spectral')

# %%
sns.barplot(x='target',y='ca',hue='sex',data=heart1_dataset,palette='mako')

# %%
sns.barplot(x='sex',y='oldpeak',hue='target',palette='rainbow',data=heart1_dataset)

# %%
heart1_dataset['fbs'].value_counts()
# Out:
# 0    872
# 1    153
# Name: fbs, dtype: int64

# %%
sns.barplot(x='fbs',y='chol',hue='target',data=heart1_dataset,palette='plasma')

# %%
sns.barplot(x='sex',y='target',hue='fbs',data=heart1_dataset)

# %%
gen=pd.crosstab(heart1_dataset['sex'],heart1_dataset['target'])
print(gen)
# Out:
# target    0    1
# sex
# 0        86  226
# 1       413  300

# %%
gen.plot(kind='bar',stacked=True,color=['green','yellow'],grid=False)

# %%
temp=pd.crosstab(index=heart1_dataset['sex'],
columns=[heart1_dataset['thal']],
margins=True)
temp
# Out:
# thal  0   1    2    3   All
# sex
# 0     3   4  252   53   312
# 1     4  60  292  357   713
# All   7  64  544  410  1025

# %%
temp.plot(kind='bar',stacked=True)
plt.show()

# %%
temp=pd.crosstab(index=heart1_dataset['target'],
                 columns=[heart1_dataset['thal']],
                 margins=True)
temp
# Out:
# thal    0   1    2    3   All
# target
# 0       4  43  132  320   499
# 1       3  21  412   90   526
# All     7  64  544  410  1025

# %%
temp.plot(kind='bar',stacked=True)
plt.show()

# %%
chest_pain=pd.crosstab(heart1_dataset['cp'],heart1_dataset['target'])
chest_pain
# Out:
# target    0    1
# cp
# 0       375  122
# 1        33  134
# 2        65  219
# 3        26   51

# %%
chest_pain.plot(kind='bar',stacked=True,color=['purple','blue'],grid=False)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
StandardScaler=StandardScaler()
columns_to_scale=['age','trestbps','chol','thalach','oldpeak']
heart1_dataset[columns_to_scale]=StandardScaler.fit_transform(heart1_dataset[columns_to_scale])

# %%
heart1_dataset.head()
# Out:
#         age  sex  cp  trestbps      chol  fbs  restecg   thalach  exang  \
# 0 -0.268437    1   0 -0.377636 -0.659332    0        1  0.821321      0
# 1 -0.158157    1   0  0.479107 -0.833861    1        0  0.255968      1
# 2  1.716595    1   0  0.764688 -1.396233    0        1 -1.048692      1
# 3  0.724079    1   0  0.936037 -0.833861    0        1  0.516900      0
# 4  0.834359    0   0  0.364875  0.930822    1        1 -1.874977      0
#
#     oldpeak  slope  ca  thal  target
# 0 -0.060888      2   2     3       0
# 1  1.727137      0   0     3       0
# 2  1.301417      0   0     3       0
# 3 -0.912329      2   1     3       0
# 4  0.705408      1   3     2       0

# %%
x=heart1_dataset.drop(['target'],axis=1)
y=heart1_dataset['target']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=20)

# %%
print('x_train-',x_train.size) 
print('x_test-',x_test.size)
print('x_train-',y_train.size) 
print('x_test-',y_test.size)
# Out:
# x_train- 9321
# x_test- 4004
# x_train- 717
# x_test- 308

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

model1=lr.fit(x_train,y_train)
prediction1=model1.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,prediction1)
cm
# Out:
# array([[115,  38],
#        [ 19, 136]], dtype=int64)

# %%
sns.heatmap(cm,annot=True,cmap='BuPu')

# %%
TP=cm[0][0]
TN=cm[1][1]
FN=cm[1][0]
FP=cm[0][1]
print('Testing Accuracy:',(TP+TN)/(TP+TN+FN+FP))
# Out:
# Testing Accuracy: 0.814935064935065

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,prediction1)
# Out:
# 0.814935064935065

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,prediction1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80       153
#            1       0.78      0.88      0.83       155
#
#     accuracy                           0.81       308
#    macro avg       0.82      0.81      0.81       308
# weighted avg       0.82      0.81      0.81       308

# %%
from sklearn.tree import  DecisionTreeClassifier
dtc=DecisionTreeClassifier()
model2=dtc.fit(x_train,y_train)
prediction2=model2.predict(x_test)
cm2=confusion_matrix(y_test,prediction2)

# %%
cm2
# Out:
# array([[153,   0],
#        [  3, 152]], dtype=int64)

# %%
accuracy_score(y_test,prediction2)
# Out:
# 0.9902597402597403

# %%
print(classification_report(y_test,prediction2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       153
#            1       1.00      0.98      0.99       155
#
#     accuracy                           0.99       308
#    macro avg       0.99      0.99      0.99       308
# weighted avg       0.99      0.99      0.99       308

# %%
from sklearn.ensemble import  RandomForestClassifier
rfc= RandomForestClassifier()
model3=rfc.fit(x_train,y_train)
prediction3=model3.predict(x_test)
confusion_matrix(y_test,prediction3)
# Out:
# array([[153,   0],
#        [  0, 155]], dtype=int64)

# %%
accuracy_score(y_test,prediction3)
# Out:
# 1.0

# %%
print(classification_report(y_test,prediction3))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       153
#            1       1.00      1.00      1.00       155
#
#     accuracy                           1.00       308
#    macro avg       1.00      1.00      1.00       308
# weighted avg       1.00      1.00      1.00       308

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
from sklearn.svm import SVC
svm=SVC()
model4=svm.fit(x_train,y_train)
prediction4=model4.predict(x_test)
cm4=confusion_matrix(y_test,prediction4)

# %%
cm4
# Out:
# array([[125,  28],
#        [ 10, 145]], dtype=int64)

# %%
accuracy_score(y_test,prediction4)
# Out:
# 0.8766233766233766

# %%
from sklearn.naive_bayes import  GaussianNB
NB=GaussianNB()
model5=NB.fit(x_train,y_train)
prediction5=model5.predict(x_test)
cm5=confusion_matrix(y_test,prediction5)

# %%
cm5
# Out:
# array([[114,  39],
#        [ 21, 134]], dtype=int64)

# %%
accuracy_score(y_test,prediction5)
# Out:
# 0.8051948051948052

# %%
print('cm4',cm4)
print('--------------')
print('cm5',cm5)
# Out:
# cm4 [[125  28]
#  [ 10 145]]
# --------------
# cm5 [[114  39]
#  [ 21 134]]

# %%
from sklearn.neighbors import  KNeighborsClassifier
KMN=KNeighborsClassifier()
model6=KMN.fit(x_train,y_train)
prediction6=model6.predict(x_test)
cm6=confusion_matrix(y_test,prediction5)
cm6
# Out:
# array([[114,  39],
#        [ 21, 134]], dtype=int64)

# %%
print('KMN:',accuracy_score(y_test,prediction6))
print('lr:',accuracy_score(y_test,prediction1))
print('dtc:',accuracy_score(y_test,prediction2))
print('rfc:',accuracy_score(y_test,prediction3))
print('NB:',accuracy_score(y_test,prediction4))
print('SVC:',accuracy_score(y_test,prediction5))
# Out:
# KMN: 0.827922077922078
# lr: 0.814935064935065
# dtc: 0.9902597402597403
# rfc: 1.0
# NB: 0.8766233766233766
# SVC: 0.8051948051948052

# %%
## best accuracy is given by randomforestclassifier:100

# %%
##followed by dtc and NB:99&87
